# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# Load the dataset
dataset = pd.read_csv('diabetes.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Build the ANN
classifier = tf.keras.Sequential([
    tf.keras.layers.Dense(units=8, activation='relu', kernel_initializer='uniform', input_dim=8),
    tf.keras.layers.Dense(units=8, kernel_initializer='uniform', activation='relu'),
    tf.keras.layers.Dense(units=1, kernel_initializer='uniform', activation='sigmoid')
])

# Compile the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Fit the ANN to the Training set
classifier.fit(X_train, y_train, batch_size=10, epochs=100)

# Make Predictions
y_pred = (classifier.predict(X_test) > 0.5)

# Create a Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize the Confusion Matrix
sns.heatmap(cm, fmt=".0f", xticklabels=['Diabetes_yes', 'Diabetes_no'],
            yticklabels=['Diabetes_yes', 'Diabetes_no'], annot=True)

# Predict a New Data Point
new_data = np.array([[1, 97, 64, 0, 0, 25.6, 0.201, 30]])
new_data = sc.transform(new_data)
outcome = classifier.predict(new_data)
print("The Outcome of the Patient is:", "Diabetes" if outcome > 0.5 else "No Diabetes")

# Calculate Performance Metrics
TP, FP, FN, TN = cm.ravel()
TPR = TP / (TP + FN)
TNR = TN / (TN + FP)
PPV = TP / (TP + FP)
NPV = TN / (TN + FN)
FPR = FP / (FP + TN)
FNR = FN / (TP + FN)
FDR = FP / (TP + FP)
ACC = (TP + TN) / (TP + FP + FN + TN)

print("Recall:", TPR)
print("Specificity:", TNR)
print("Precision:", PPV)
print("Negative Predictive Value:", NPV)
print("False Positive Rate:", FPR)
print("False Negative Rate:", FNR)
print("False Discovery Rate:", FDR)
print("Accuracy:", ACC)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 2ms/step - loss: 0.6898 - accuracy: 0.6417
# Epoch 2/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6726 - accuracy: 0.6401
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5966 - accuracy: 0.6401
# Epoch 4/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5417 - accuracy: 0.6401
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.6694
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5183 - accuracy: 0.7736
# Epoch 7/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5134 - accuracy: 0.7769
# Epoch 8/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.7720
# Epoch 9/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.7638
# Epoch 10/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5004 - accuracy: 0.7704
# Epoch 11/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4963 - accuracy: 0.7687
# Epoch 12/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4939 - accuracy: 0.7704
# Epoch 13/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4909 - accuracy: 0.7622
# Epoch 14/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7704
# Epoch 15/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7655
# Epoch 16/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.7704
# Epoch 17/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4805 - accuracy: 0.7704
# Epoch 18/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 0.7638
# Epoch 19/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4742 - accuracy: 0.7687
# Epoch 20/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4721 - accuracy: 0.7720
# Epoch 21/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.7720
# Epoch 22/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.7704
# Epoch 23/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4658 - accuracy: 0.7720
# Epoch 24/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.7687
# Epoch 25/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.7720
# Epoch 26/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.7736
# Epoch 27/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4623 - accuracy: 0.7752
# Epoch 28/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4614 - accuracy: 0.7785
# Epoch 29/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7785
# Epoch 30/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.7801
# Epoch 31/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.7752
# Epoch 32/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4554 - accuracy: 0.7883
# Epoch 33/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.7818
# Epoch 34/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4569 - accuracy: 0.7834
# Epoch 35/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4560 - accuracy: 0.7866
# Epoch 36/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.7834
# Epoch 37/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7866
# Epoch 38/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7785
# Epoch 39/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7915
# Epoch 40/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4510 - accuracy: 0.7866
# Epoch 41/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4500 - accuracy: 0.7818
# Epoch 42/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4517 - accuracy: 0.7866
# Epoch 43/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.7834
# Epoch 44/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.7899
# Epoch 45/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7883
# Epoch 46/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4496 - accuracy: 0.7932
# Epoch 47/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7932
# Epoch 48/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7866
# Epoch 49/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4475 - accuracy: 0.7866
# Epoch 50/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4474 - accuracy: 0.7932
# Epoch 51/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4473 - accuracy: 0.7915
# Epoch 52/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4461 - accuracy: 0.7834
# Epoch 53/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4453 - accuracy: 0.7932
# Epoch 54/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4452 - accuracy: 0.7834
# Epoch 55/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.7915
# Epoch 56/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4449 - accuracy: 0.7883
# Epoch 57/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4461 - accuracy: 0.7883
# Epoch 58/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.7948
# Epoch 59/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4455 - accuracy: 0.7899
# Epoch 60/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.7818
# Epoch 61/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7915
# Epoch 62/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7932
# Epoch 63/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4438 - accuracy: 0.7997
# Epoch 64/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4438 - accuracy: 0.7899
# Epoch 65/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7964
# Epoch 66/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4437 - accuracy: 0.7948
# Epoch 67/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7899
# Epoch 68/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7948
# Epoch 69/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.7883
# Epoch 70/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.7964
# Epoch 71/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7899
# Epoch 72/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4417 - accuracy: 0.7932
# Epoch 73/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.7964
# Epoch 74/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4422 - accuracy: 0.7948
# Epoch 75/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.7899
# Epoch 76/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.7899
# Epoch 77/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.7964
# Epoch 78/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.7964
# Epoch 79/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.7915
# Epoch 80/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.7866
# Epoch 81/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4406 - accuracy: 0.7948
# Epoch 82/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4399 - accuracy: 0.7899
# Epoch 83/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7948
# Epoch 84/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.7948
# Epoch 85/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4402 - accuracy: 0.7964
# Epoch 86/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.7997
# Epoch 87/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4402 - accuracy: 0.7964
# Epoch 88/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7915
# Epoch 89/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4392 - accuracy: 0.7899
# Epoch 90/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4393 - accuracy: 0.7948
# Epoch 91/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4408 - accuracy: 0.7997
# Epoch 92/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.7980
# Epoch 93/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4396 - accuracy: 0.8029
# Epoch 94/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4400 - accuracy: 0.7980
# Epoch 95/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7997
# Epoch 96/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4423 - accuracy: 0.7964
# Epoch 97/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.8046
# Epoch 98/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.7948
# Epoch 99/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4381 - accuracy: 0.7948
# Epoch 100/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4383 - accuracy: 0.7964
# 5/5 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 22ms/step
# The Outcome of the Patient is: No Diabetes
# Recall: 0.8440366972477065
# Specificity: 0.6666666666666666
# Precision: 0.8598130841121495
# Negative Predictive Value: 0.6382978723404256
# False Positive Rate: 0.3333333333333333
# False Negative Rate: 0.1559633027522936
# False Discovery Rate: 0.14018691588785046
# Accuracy: 0.7922077922077922

# %%
datasett = dataset. iloc[:, :-1]
datasett
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %% [markdown]
# Inspection see's 0 values for Insulin, preprocessing needed?

# %%
import matplotlib.pyplot as plt
pos   = [1, 2,3, 4, 5,6, 7, 8]
label = list(datasett.columns)
plt.figure()
ax = plt.subplot(111)
plt.violinplot(datasett,pos, vert=False)
ax.set_yticks(pos)
ax.set_yticklabels(label)
# Out:
# [Text(0, 1, 'Pregnancies'),
#  Text(0, 2, 'Glucose'),
#  Text(0, 3, 'BloodPressure'),
#  Text(0, 4, 'SkinThickness'),
#  Text(0, 5, 'Insulin'),
#  Text(0, 6, 'BMI'),
#  Text(0, 7, 'DiabetesPedigreeFunction'),
#  Text(0, 8, 'Age')]

# %% [markdown]
# Large Range for Insulin values suggests data should be inspected fro outliers?

# %%
import matplotlib.pyplot as plt
pos   = [1, 2,3, 4, 5,6, 7, 8]
label = list(datasett.columns)
plt.figure()
ax = plt.subplot(111)
plt.violinplot(datasett,pos, vert=False)
ax.set_yticks(pos)
ax.set_yticklabels(label)

ax.set_xlim(left=-20, right=240)
# Out:
# (-20.0, 240.0)

# %% [markdown]
# Skin Thickness seems to have alot of near 0 values, Is this right?

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

# Load the dataset
dataset = pd.read_csv('diabetes.csv')
dataset['Insulin']=dataset['Insulin'].replace(0,dataset['Insulin'].mean())
dataset['SkinThickness']=dataset['SkinThickness'].replace(0,dataset['SkinThickness'].mean())
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Build the ANN
classifier = tf.keras.Sequential([
    tf.keras.layers.Dense(units=8, activation='relu', kernel_initializer='uniform', input_dim=8),
    tf.keras.layers.Dense(units=8, kernel_initializer='uniform', activation='relu'),
    tf.keras.layers.Dense(units=1, kernel_initializer='uniform', activation='sigmoid')
])

# Compile the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Fit the ANN to the Training set
classifier.fit(X_train, y_train, batch_size=10, epochs=100)

# Make Predictions
y_pred = (classifier.predict(X_test) > 0.5)

# Create a Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize the Confusion Matrix
sns.heatmap(cm, fmt=".0f", xticklabels=['Diabetes_yes', 'Diabetes_no'],
            yticklabels=['Diabetes_yes', 'Diabetes_no'], annot=True)

# Predict a New Data Point
new_data = np.array([[1, 97, 64, 0, 0, 25.6, 0.201, 30]])
new_data = sc.transform(new_data)
outcome = classifier.predict(new_data)
print("The Outcome of the Patient is:", "Diabetes" if outcome > 0.5 else "No Diabetes")

# Calculate Performance Metrics
TP, FP, FN, TN = cm.ravel()
TPR = TP / (TP + FN)
TNR = TN / (TN + FP)
PPV = TP / (TP + FP)
NPV = TN / (TN + FN)
FPR = FP / (FP + TN)
FNR = FN / (TP + FN)
FDR = FP / (TP + FP)
ACC = (TP + TN) / (TP + FP + FN + TN)

print("Recall:", TPR)
print("Specificity:", TNR)
print("Precision:", PPV)
print("Negative Predictive Value:", NPV)
print("False Positive Rate:", FPR)
print("False Negative Rate:", FNR)
print("False Discovery Rate:", FDR)
print("Accuracy:", ACC)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 1s 2ms/step - loss: 0.6892 - accuracy: 0.6352
# Epoch 2/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6675 - accuracy: 0.6401
# Epoch 3/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6038 - accuracy: 0.7199
# Epoch 4/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5360 - accuracy: 0.7590
# Epoch 5/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7704
# Epoch 6/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.7671
# Epoch 7/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4825 - accuracy: 0.7687
# Epoch 8/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7736
# Epoch 9/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.7752
# Epoch 10/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4745 - accuracy: 0.7736
# Epoch 11/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.7720
# Epoch 12/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4716 - accuracy: 0.7801
# Epoch 13/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4697 - accuracy: 0.7687
# Epoch 14/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7720
# Epoch 15/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.7720
# Epoch 16/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.7752
# Epoch 17/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.7736
# Epoch 18/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.7736
# Epoch 19/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.7769
# Epoch 20/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.7752
# Epoch 21/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.7752
# Epoch 22/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4628 - accuracy: 0.7752
# Epoch 23/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.7769
# Epoch 24/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.7752
# Epoch 25/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4613 - accuracy: 0.7736
# Epoch 26/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.7785
# Epoch 27/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.7769
# Epoch 28/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4602 - accuracy: 0.7752
# Epoch 29/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.7801
# Epoch 30/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.7801
# Epoch 31/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7769
# Epoch 32/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.7818
# Epoch 33/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4584 - accuracy: 0.7801
# Epoch 34/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.7801
# Epoch 35/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4576 - accuracy: 0.7801
# Epoch 36/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4570 - accuracy: 0.7801
# Epoch 37/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4566 - accuracy: 0.7818
# Epoch 38/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7834
# Epoch 39/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.7818
# Epoch 40/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.7850
# Epoch 41/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.7801
# Epoch 42/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4546 - accuracy: 0.7899
# Epoch 43/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4544 - accuracy: 0.7834
# Epoch 44/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.7883
# Epoch 45/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4537 - accuracy: 0.7850
# Epoch 46/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4538 - accuracy: 0.7818
# Epoch 47/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4525 - accuracy: 0.7915
# Epoch 48/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4527 - accuracy: 0.7883
# Epoch 49/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.7866
# Epoch 50/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4512 - accuracy: 0.7883
# Epoch 51/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4516 - accuracy: 0.7883
# Epoch 52/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4520 - accuracy: 0.7883
# Epoch 53/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4504 - accuracy: 0.7866
# Epoch 54/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4510 - accuracy: 0.7915
# Epoch 55/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.7850
# Epoch 56/100
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4497 - accuracy: 0.7883
# Epoch 57/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7834
# Epoch 58/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 0.7883
# Epoch 59/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4503 - accuracy: 0.7883
# Epoch 60/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.7915
# Epoch 61/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4484 - accuracy: 0.7883
# Epoch 62/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7883
# Epoch 63/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4467 - accuracy: 0.7883
# Epoch 64/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7899
# Epoch 65/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7866
# Epoch 66/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4463 - accuracy: 0.7899
# Epoch 67/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.7883
# Epoch 68/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4447 - accuracy: 0.7866
# Epoch 69/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4450 - accuracy: 0.7866
# Epoch 70/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4444 - accuracy: 0.7915
# Epoch 71/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4436 - accuracy: 0.7948
# Epoch 72/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4435 - accuracy: 0.7980
# Epoch 73/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.7932
# Epoch 74/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.7932
# Epoch 75/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.7899
# Epoch 76/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4425 - accuracy: 0.8013
# Epoch 77/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8029
# Epoch 78/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4411 - accuracy: 0.7932
# Epoch 79/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4412 - accuracy: 0.7932
# Epoch 80/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4401 - accuracy: 0.7964
# Epoch 81/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4402 - accuracy: 0.7948
# Epoch 82/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4399 - accuracy: 0.7964
# Epoch 83/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4403 - accuracy: 0.7964
# Epoch 84/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4392 - accuracy: 0.7948
# Epoch 85/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4390 - accuracy: 0.7980
# Epoch 86/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4394 - accuracy: 0.7948
# Epoch 87/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4386 - accuracy: 0.7980
# Epoch 88/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4379 - accuracy: 0.7948
# Epoch 89/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.7997
# Epoch 90/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4384 - accuracy: 0.7948
# Epoch 91/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.7997
# Epoch 92/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.7964
# Epoch 93/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4366 - accuracy: 0.8013
# Epoch 94/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4367 - accuracy: 0.8013
# Epoch 95/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.7964
# Epoch 96/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4361 - accuracy: 0.8013
# Epoch 97/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4358 - accuracy: 0.7964
# Epoch 98/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7997
# Epoch 99/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4355 - accuracy: 0.7980
# Epoch 100/100
# 62/62 [==============================] - 0s 2ms/step - loss: 0.4349 - accuracy: 0.7948
# 5/5 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 30ms/step
# The Outcome of the Patient is: No Diabetes
# Recall: 0.8392857142857143
# Specificity: 0.6904761904761905
# Precision: 0.8785046728971962
# Negative Predictive Value: 0.6170212765957447
# False Positive Rate: 0.30952380952380953
# False Negative Rate: 0.16071428571428573
# False Discovery Rate: 0.12149532710280374
# Accuracy: 0.7987012987012987

# %% [markdown]
# | Original Code|Preprocessed|
# | --- | --- |
# | Recall: 0.8440366972477065|Recall: 0.8392857142857143|
# | --- | --- |
# |Specificity: 0.6666666666666666|Specificity: 0.6904761904761905|
# | --- | --- |
# |Precision: 0.8598130841121495|Precision: 0.8785046728971962|
# | --- | --- |
# |Negative Predictive Value: 0.6382978723404256|Negative Predictive Value: 0.6170212765957447|
# | --- | --- |
# |False Positive Rate: 0.3333333333333333|False Positive Rate: 0.30952380952380953|
# | --- | --- |
# |False Negative Rate: 0.1559633027522936|False Negative Rate: 0.16071428571428573|
# | --- | --- |
# |False Discovery Rate: 0.14018691588785046|False Discovery Rate: 0.12149532710280374|
# | --- | --- |
# |Accuracy: 0.7922077922077922|Accuracy: 0.7987012987012987
